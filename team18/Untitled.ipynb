# %% [markdown]
# ## Детские сады

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
from bs4 import BeautifulSoup
import lxml
import pprint
import pandas as pd

import requests
from bs4 import BeautifulSoup
import time
import random
import pprint
import pandas as pd
import mcfg
import json
import warnings
from selenium import webdriver
import numpy as np
from sqlalchemy import create_engine
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_25536\2917839375.py:7: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
driver = webdriver.Chrome()

# %%
url = "https://www.mos.ru/map/?screens=%5B%22objectsList%22%5D&categories=%5B%2237%22%5D&kind=48&mapParams=%7B%22cp%22%3A%7B%22lat%22%3A55.65279803318956%2C%22lng%22%3A38.02093505859376%7D%2C%22p1%22%3A%7B%22lat%22%3A56.310443171346%2C%22lng%22%3A39.77874755859376%7D%2C%22p2%22%3A%7B%22lat%22%3A54.983918190363234%2C%22lng%22%3A36.26312255859376%7D%2C%22z%22%3A9%7D&kindTitle=%D0%94%D0%B5%D1%82%D1%81%D0%BA%D0%B8%D0%B5+%D1%81%D0%B0%D0%B4%D1%8B"

# %%
driver.get(url)

# %%
html = driver.page_source

with open("page_kids.html", "w", encoding="utf-8") as f:
    f.write(html)

# %%
with open("page_kids.html", "r", encoding="utf-8") as file:
    html = file.read()

soup = BeautifulSoup(html, "html.parser")
divs = soup.find_all("div", class_="src-components-Sidebar-components-ObjectsList-___styles-module__item___36R2V")

# %%
divs
# Out:
# [<div class="src-components-Sidebar-components-ObjectsList-___styles-module__item___36R2V"><div><div class="src-components-Sidebar-components-ObjectsList-___styles-module__description___32MG0"><div class="src-components-Sidebar-components-ObjectsList-___styles-module__categories___2pFkS">Раменки</div><div class="src-components-Sidebar-components-ObjectsList-___styles-module__object_name___2UpP6">ENGLISH NURSERY AND PRIMARY SCHOOL, английский частный детский сад</div><div class="src-components-Sidebar-components-ObjectsList-___styles-module__address___A19Is">Пырьева 10а</div></div></div></div>,
# ...

# %%
len(divs)
# Out:
# 135
